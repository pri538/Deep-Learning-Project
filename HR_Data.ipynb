# %% [markdown]
# <a href="https://colab.research.google.com/github/pri538/Deep-Learning-Project/blob/main/HR_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import warnings
import pandas as pd

# %%
df=pd.read_csv('/content/HR DATA MODIFIED.csv')
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    Age  Attrition BusinessTravel  DailyRate              Department  \
# 0   51          0  Travel_Rarely        684  Research & Development
# 1   52          0  Travel_Rarely        699  Research & Development
# 2   42          0  Travel_Rarely        532  Research & Development
# 3   47          0  Travel_Rarely        359  Research & Development
# 4   46          0  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             162                        1    Male          51
# 1             259                        3    Male          65
# 2             319                        3    Male          58
# 3            1443                        1  Female          82
# 4            1863                        1  Female          45
#
#    JobInvolvement  JobLevel            JobRole  JobSatisfaction MaritalStatus  \
# 0               3         5  Research Director                3        Single
# 1               2         5            Manager                3       Married
# 2               3         5            Manager                4       Married
# 3               3         4  Research Director                3       Married
# 4               4         4    Sales Executive                1      Divorced
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0          19537         6462                   7       1         0
# 1          19999         5678                   0       1         0
# 2          19232         4933                   1       1         0
# 3          17169        26703                   3       1         0
# 4          13225         7739                   2       1         0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 13                  3                         3
# 1                 14                  3                         1
# 2                 11                  3                         4
# 3                 19                  3                         2
# 4                 12                  3                         4
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             80                 0                 23                      5
# 1             80                 1                 34                      5
# 2             80                 0                 22                      3
# 3             80                 2                 26                      2
# 4             80                 1                 25                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              20                  18
# 1                3              33                  18
# 2                3              22                  17
# 3                4              20                  17
# 4                3              19                  17
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                       15                    15
# 1                       11                     9
# 2                       11                    15
# 3                        5                     6
# 4                        2                     8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   int64
#  22  OverTime                  1470 non-null   int64
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(29), object(6)
# memory usage: 402.1+ KB

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement     JobLevel  JobSatisfaction  MonthlyIncome  \
# count     1470.000000  1470.000000      1470.000000    1470.000000
# mean         2.729932     2.063946         2.728571    6502.931293
# std          0.711561     1.106940         1.102846    4707.956783
# min          1.000000     1.000000         1.000000    1009.000000
# 25%          2.000000     1.000000         2.000000    2911.000000
# 50%          3.000000     2.000000         3.000000    4919.000000
# 75%          3.000000     3.000000         4.000000    8379.000000
# max          4.000000     5.000000         4.000000   19999.000000
#
#         MonthlyRate  NumCompaniesWorked  Over18     OverTime  \
# count   1470.000000         1470.000000  1470.0  1470.000000
# mean   14313.103401            2.693197     1.0     0.282993
# std     7117.786044            2.498009     0.0     0.450606
# min     2094.000000            0.000000     1.0     0.000000
# 25%     8047.000000            1.000000     1.0     0.000000
# 50%    14235.500000            2.000000     1.0     0.000000
# 75%    20461.500000            4.000000     1.0     1.000000
# max    26999.000000            9.000000     1.0     1.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        1470.000000        1470.000000               1470.000000
# mean           15.209524           3.153741                  2.712245
# std             3.659938           0.360824                  1.081209
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            18.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         1470.0       1470.000000        1470.000000
# mean            80.0          0.793878          11.279592
# std              0.0          0.852077           7.780782
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000           6.000000
# 50%             80.0          1.000000          10.000000
# 75%             80.0          1.000000          15.000000
# max             80.0          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000

# %%
df.drop(['EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)

# %%
corr=df.corr(numeric_only=True).abs()
corr.style.background_gradient(cmap='cividis')
# Out:
# <style type="text/css">
# #T_704d6_row0_col0, #T_704d6_row1_col1, #T_704d6_row2_col2, #T_704d6_row3_col3, #T_704d6_row4_col4, #T_704d6_row5_col5, #T_704d6_row6_col6, #T_704d6_row7_col7, #T_704d6_row8_col8, #T_704d6_row9_col9, #T_704d6_row10_col10, #T_704d6_row11_col11, #T_704d6_row12_col12, #T_704d6_row13_col13, #T_704d6_row14_col14, #T_704d6_row15_col15, #T_704d6_row16_col16, #T_704d6_row17_col17, #T_704d6_row18_col18, #T_704d6_row19_col19, #T_704d6_row20_col20, #T_704d6_row21_col21, #T_704d6_row22_col22, #T_704d6_row23_col23, #T_704d6_row24_col24, #T_704d6_row25_col25 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_704d6_row0_col1, #T_704d6_row1_col0, #T_704d6_row1_col23, #T_704d6_row11_col1, #T_704d6_row23_col1 {
row12_col19, #T_704d6_row14_col0, #T_704d6_row14_col3, #T_704d6_row14_col10, #T_704d6_row14_col21, #T_704d6_row16_col3, #T_704d6_row16_col8, #T_704d6_row18_col25, #T_704d6_row19_col12, #T_704d6_row20_col21, #T_704d6_row21_col3, #T_704d6_row21_col6, #T_704d6_row21_col11, #T_704d6_row21_col14, #T_704d6_row21_col20, #T_704d6_row24_col7, #T_704d6_row25_col2, #T_704d6_row25_col10, #T_704d6_row25_col18 {
#   background-color: #002758;
#   color: #f1f1f1;
# }
# #T_704d6_row0_col9, #T_704d6_row9_col0, #T_704d6_row22_col11, #T_704d6_row24_col25, #T_704d6_row25_col24 {
#   background-color: #7e7d78;
#   color: #f1f1f1;
# }
# #T_704d6_row0_col10, #T_704d6_row1_col7, #T_704d6_row2_col4, #T_704d6_row2_col17, #T_704d6_row3_col2, #T_704d6_row3_col8, #T_704d6_row3_col9, #T_704d6_row3_col17, #T_704d6_row5_col1, #T_704d6_row5_col23, #T_704d6_row5_col24, #T_704d6_row6_col8, #T_704d6_row6_col10, #T_704d6_row6_col17, #T_704d6_row6_col25, #T_704d6_row7_col1, #T_704d6_row7_col4, #T_704d6_row7_col14, #T_704d6_row7_col15, #T_704d6_row7_col20, #T_704d6_row8_col3, #T_704d6_row8_col5, #T_704d6_row8_col6, #T_704d6_row8_col19, #T_704d6_row8_col23, #T_704d6_row10_col6, #T_704d6_row10_col20, #T_704d6_row11_col2, #T_704d6_row11_col6, #T_704d6_row11_col10, #T_704d6_row11_col14, #T_704d6_row11_col18, #T_704d6_row12_col15, #T_704d6_row12_col21, #T_704d6_row13_col21, #T_704d6_row14_col7, #T_704d6_row14_col15, #T_704d6_row15_col7, #T_704d6_row15_col12, #T_704d6_row15_col14, #T_704d6_row15_col18, #T_704d6_row16_col14, #T_704d6_row16_col19, #T_704d6_row17_col2, #T_704d6_row17_col3, #T_704d6_row17_col6, #T_704d6_row18_col15, #T_704d6_row19_col16, #T_704d6_row20_col7, #T_704d6_row20_col10, #T_704d6_row20_col23, #T_704d6_row21_col12, #T_704d6_row21_col13, #T_704d6_row21_col24, #T_704d6_row23_col5, #T_704d6_row23_col8, #T_704d6_row23_col20, #T_704d6_row24_col5 {
#   background-color: #00234f;
#   color: #f1f1f1;
# }
# #T_704d6_row0_col11 {
#   background-color: #7b7a78;
#   color: #f1f1f1;
# }
# #T_704d6_row0_col12, #T_704d6_row0_col14, #T_704d6_row2_col10, #T_704d6_row3_col7, #T_704d6_row3_col13, #T_704d6_row4_col1,

# %%
cols=['YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']
sns.pairplot(df[cols],height=5)
plt.tight_layout()
plt.show()

# %%
categorical_cols=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']
fig,ax=plt.subplots(3,2,figsize=(10,8))
fig.subplots_adjust(hspace=0.5)
def count_plotter(ax,col,data=df):
    counted=df[col].value_counts()
    sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
    ax.set_title(f"{col} count graph")
    if col=='JobRole' or col=='EducationField':
       ax.set_xticklabels(labels=counted.index,rotation=90,fontsize=6)
    else:        ax.set_xticklabels(labels=counted.index,fontsize=8)
axes=[ax[0,0],ax[0,1],ax[1,0],ax[1,1],ax[2,0],ax[2,1]]
for category in categorical_cols:
    count_plotter(axes[categorical_cols.index(category)],category)
# Out:
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   else:        ax.set_xticklabels(labels=counted.index,fontsize=8)
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   else:        ax.set_xticklabels(labels=counted.index,fontsize=8)
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=counted.index,rotation=90,fontsize=6)
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   else:        ax.set_xticklabels(labels=counted.index,fontsize=8)
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=counted.index,rotation=90,fontsize=6)
# <ipython-input-11-d2a3585426cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax,x=counted.index,y=counted.values,width=0.9,palette='Set1' )
# <ipython-input-11-d2a3585426cf>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   else:        ax.set_xticklabels(labels=counted.index,fontsize=8)

# %%
df.head()
# Out:
#    Age  Attrition BusinessTravel  DailyRate              Department  \
# 0   51          0  Travel_Rarely        684  Research & Development
# 1   52          0  Travel_Rarely        699  Research & Development
# 2   42          0  Travel_Rarely        532  Research & Development
# 3   47          0  Travel_Rarely        359  Research & Development
# 4   46          0  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 6          3     Life Sciences             162
# 1                 1          4     Life Sciences             259
# 2                 4          2  Technical Degree             319
# 3                 2          4           Medical            1443
# 4                 3          3  Technical Degree            1863
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        1    Male          51               3         5
# 1                        3    Male          65               2         5
# 2                        3    Male          58               3         5
# 3                        1  Female          82               3         4
# 4                        1  Female          45               4         4
#
#              JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0  Research Director                3        Single          19537
# 1            Manager                3       Married          19999
# 2            Manager                4       Married          19232
# 3  Research Director                3       Married          17169
# 4    Sales Executive                1      Divorced          13225
#
#    MonthlyRate  NumCompaniesWorked  OverTime  PercentSalaryHike  \
# 0         6462                   7         0                 13
# 1         5678                   0         0                 14
# 2         4933                   1         0                 11
# 3        26703                   3         0                 19
# 4         7739                   2         0                 12
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         3                 0
# 1                  3                         1                 1
# 2                  3                         4                 0
# 3                  3                         2                 2
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                 23                      5                3              20
# 1                 34                      5                3              33
# 2                 22                      3                3              22
# 3                 26                      2                4              20
# 4                 25                      5                3              19
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  18                       15                    15
# 1                  18                       11                     9
# 2                  17                       11                    15
# 3                  17                        5                     6
# 4                  17                        2                     8

# %%
def make_FacetGrid(df,col_name,x_value,hue='Gender'):
    facet=sns.FacetGrid(data=df,col=col_name,hue=hue,aspect=1,palette=['b','r'],col_wrap=3)
    facet.map(sns.kdeplot,x_value,fill=True)
    facet.set(xlim=[0,df[x_value].max()])
    facet.add_legend(label_order=df[hue].unique())
    plt.tight_layout()
col_names=['BusinessTravel','JobRole','Department']
x_values=['DailyRate','MonthlyIncome','TotalWorkingYears']

for i in range(len(col_names)):
    make_FacetGrid(df,col_names[i],x_values[i])
plt.show()

# %%
df_heatmap1=df.groupby(['JobRole','JobSatisfaction']).MonthlyIncome.mean().unstack(level=1)
df_heatmap2=df.groupby(['JobInvolvement','JobLevel']).MonthlyRate.mean().unstack(level=1)
df_heatmap2
# Out:
# JobLevel                   1             2             3             4  \
# JobInvolvement
# 1               12661.666667  15916.314286  14240.900000  21197.000000
# 2               13853.708029  15410.187500  14519.954545  13940.370370
# 3               13488.798742  14447.791798  14817.562500  14592.854839
# 4               14905.051724  14445.703704  13781.285714  14024.857143
#
# JobLevel                   5
# JobInvolvement
# 1               14848.000000
# 2               15923.117647
# 3               13255.860465
# 4               18149.250000

# %%
#plt.figure(figsize=(8,4))
fig,ax=plt.subplots(3,2,figsize=(15,13))
fig.suptitle('General Statistics')
fig.subplots_adjust(wspace=0.4,hspace=0.5)
sns.boxplot(ax=ax[0,0],data=df,y='Department',x='TotalWorkingYears',hue='Gender',palette=['#ffec00','#3ee016'])
ax[0,0].set_title('Ages by Department',fontsize=14)
sns.boxplot(ax=ax[0,1],data=df,y='EducationField',x='Age',hue='Gender',palette=['#ffec00','#3ee016'])
ax[0,1].set_title('Ages by Education Field',fontsize=14)
sns.heatmap(ax=ax[1,0],data=df_heatmap1,square=True,linewidth=1,cmap='Reds')
ax[1,0].set_title('Job Role-Satisfaction Mapping',fontsize=14)
sns.heatmap(ax=ax[1,1],data=df_heatmap2,square=True,linewidth=1,cmap='Blues')
ax[1,1].set_title('Job Level-Involvement Mapping',fontsize=14)
sns.histplot(ax=ax[2,0],data=df,x='PercentSalaryHike',hue='Gender',multiple='stack')
ax[2,0].set_title('Distribution of Salary Percent Hike',fontsize=14)
sns.histplot(ax=ax[2,1],data=df,x='YearsAtCompany',hue='Gender',multiple='stack',palette='Set1')
ax[2,1].set_title('Distribution of Worked Year in Company',fontsize=14)
plt.show()

# %%
sns.pairplot(df[['MonthlyIncome','JobLevel','TotalWorkingYears','MonthlyRate','Age']])

# %%
import altair as alt
from vega_datasets import data

# Load data
cars = data.cars()

# Define selections
brush = alt.selection_interval(encodings=['x'])
click = alt.selection_single(encodings=['color'])

# Create scatter plot
scatter = alt.Chart(cars).mark_circle().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    color=alt.condition(click, 'Origin:N', alt.value('lightgray')),
).add_selection(
    brush, click
)

# Create bar chart
bars = alt.Chart(cars).mark_bar().encode(
    y='Origin:N',
    color='Origin:N',
    x='count(Origin):Q'
).transform_filter(
    click
)

# Combine plots
scatter | bars
# Out:
# alt.HConcatChart(...)

# %%
scatter
# Out:
# alt.Chart(...)
